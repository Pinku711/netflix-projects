# %% [markdown]
# ## Netflix Dataset Analysis
#
# The netflix Dataset has information about the TV Shows and Movies available on Netflix till 2021, but here i have search the subscriber as per our dataset

# %%
# Importing the dataset
import pandas as pd
Netflix=pd.read_csv(r"C:\Users\pc\Desktop\Netflix Userbase.csv") # Loading the dataset

# %%
Netflix # Here present the top 5 rows and top bottom rows with total columns
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 0           1             Basic               10  15-01-2022
# 1           2           Premium               15  05-09-2021
# 2           3          Standard               12  28-02-2023
# 3           4          Standard               12  10-07-2022
# 4           5             Basic               10  01-05-2023
# ...       ...               ...              ...         ...
# 2495     2496           Premium               14  25-07-2022
# 2496     2497             Basic               15  04-08-2022
# 2497     2498          Standard               12  09-08-2022
# 2498     2499          Standard               13  12-08-2022
# 2499     2500             Basic               15  13-08-2022
#
#      Last Payment Date         Country  Age  Gender      Device Plan Duration
# 0           10-06-2023   United States   28    Male  Smartphone       1 Month
# ...

# %% [markdown]
# # Top 5 records of the dataset

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %% [markdown]
# # Bottom 5 Records of the dataset

# %%
Netflix.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 2495     2496           Premium               14  25-07-2022
# 2496     2497             Basic               15  04-08-2022
# 2497     2498          Standard               12  09-08-2022
# 2498     2499          Standard               13  12-08-2022
# 2499     2500             Basic               15  13-08-2022
#
#      Last Payment Date        Country  Age  Gender    Device Plan Duration
# 2495        12-07-2023          Spain   28  Female  Smart TV       1 Month
# 2496        14-07-2023          Spain   33  Female  Smart TV       1 Month
# 2497        15-07-2023  United States   38    Male    Laptop       1 Month
# 2498        12-07-2023         Canada   48  Female    Tablet       1 Month
# 2499        12-07-2023  United States   35  Female  Smart TV       1 Month

# %% [markdown]
# # This step show the dataset how many rows and columns

# %%
Netflix.shape
# Out:
# (2500, 10)

# %% [markdown]
# # To shows No. of total Values (elements) to the Dataset

# %%
Netflix.size
# Out:
# 25000

# %% [markdown]
# # To shows each columns name with this command

# %%
Netflix.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %% [markdown]
# # Show the Data type of each columns

# %%
Netflix.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %% [markdown]
# # It is show the Indexes, columns, data-types of each column, memory of usage

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %% [markdown]
# # Task 1. Is there Duplicate Record in this dataset? If yes, then remove the duplicate records.
#
#
# # Duplicate()

# %%
Netflix.head(20)
# Out:
#     User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0         1             Basic               10  15-01-2022        10-06-2023
# 1         2           Premium               15  05-09-2021        22-06-2023
# 2         3          Standard               12  28-02-2023        27-06-2023
# 3         4          Standard               12  10-07-2022        26-06-2023
# 4         5             Basic               10  01-05-2023        28-06-2023
# 5         6           Premium               15  18-03-2022        27-06-2023
# 6         7          Standard               12  09-12-2021        25-06-2023
# 7         8             Basic               10  02-04-2023        24-06-2023
# 8         9          Standard               12  20-10-2022        23-06-2023
# 9        10           Premium               15  07-01-2023        22-06-2023
# 10       11             Basic               10  16-05-2022        22-06-2023
# ...

# %%
Netflix.shape
# Out:
# (2500, 10)

# %% [markdown]
# # To check the row wise and detect the Duplicate rows

# %%
Netflix[Netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User ID, Subscription Type, Monthly Revenue, Join Date, Last Payment Date, Country, Age, Gender, Device, Plan Duration]
# Index: []

# %% [markdown]
# # if duplicates data available remove the duplicated data

# %%
Netflix.drop_duplicates(inplace = True)

# %%
Netflix[Netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User ID, Subscription Type, Monthly Revenue, Join Date, Last Payment Date, Country, Age, Gender, Device, Plan Duration]
# Index: []

# %% [markdown]
# # to check and verify the duplicates dataset

# %%
Netflix.shape
# Out:
# (2500, 10)

# %% [markdown]
# # Task 2:-Find the NUll Value presetn in this data? Show with heatmap.
#
# # Isnull()
#
# # To Show where null value is present

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
Netflix.isnull()
# Out:
#       User ID  Subscription Type  Monthly Revenue  Join Date  \
# 0       False              False            False      False
# 1       False              False            False      False
# 2       False              False            False      False
# 3       False              False            False      False
# 4       False              False            False      False
# ...       ...                ...              ...        ...
# 2495    False              False            False      False
# 2496    False              False            False      False
# 2497    False              False            False      False
# 2498    False              False            False      False
# 2499    False              False            False      False
#
#       Last Payment Date  Country    Age  Gender  Device  Plan Duration
# 0                 False    False  False   False   False          False
# 1                 False    False  False   False   False          False
# ...

# %% [markdown]
# # to check the all null value with sum funcionality also

# %%
Netflix.isnull().sum() # here is no null value
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %% [markdown]
# # Seaborn library (heat-map)

# %%
import seaborn as sns # import the seabron library

# %%
sns.heatmap(Netflix.isnull()) # to present dataset with heatmap
# Out:
# <Axes: >

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
Netflix.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %%
Netflix['Date_N'] = pd.to_datetime(Netflix["Join Date"])
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5208\494120783.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   Netflix['Date_N'] = pd.to_datetime(Netflix["Join Date"])

# %% [markdown]
# # In which year highest number of the subscription? Shows with Bar Graph.
#
#
# # to_datetime

# %%
# dtypes
Netflix.dtypes
# Out:
# User ID                       int64
# Subscription Type            object
# Monthly Revenue               int64
# Join Date                    object
# Last Payment Date            object
# Country                      object
# Age                           int64
# Gender                       object
# Device                       object
# Plan Duration                object
# Date_N               datetime64[ns]
# dtype: object

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration     Date_N
# 0   United States   28    Male  Smartphone       1 Month 2022-01-15
# 1          Canada   35  Female      Tablet       1 Month 2021-09-05
# 2  United Kingdom   42    Male    Smart TV       1 Month 2023-02-28
# 3       Australia   51  Female      Laptop       1 Month 2022-07-10
# 4         Germany   33    Male  Smartphone       1 Month 2023-05-01

# %% [markdown]
# # It shows the occurence of all individual Years in Date column.

# %%
Netflix['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2022    2448
# 2023      38
# 2021      14
# Name: count, dtype: int64

# %% [markdown]
# # Bar Graph

# %%
Netflix['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# # Show the subcription that were join in the year 2022.
#
# # Creating new column

# %%
Netflix.head(2)
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
#
#          Country  Age  Gender      Device Plan Duration     Date_N
# 0  United States   28    Male  Smartphone       1 Month 2022-01-15
# 1         Canada   35  Female      Tablet       1 Month 2021-09-05

# %% [markdown]
# # to create the new year column; it will be consider only year

# %%
Netflix['year'] = Netflix['Date_N'].dt.year

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration     Date_N  year
# 0   United States   28    Male  Smartphone       1 Month 2022-01-15  2022
# 1          Canada   35  Female      Tablet       1 Month 2021-09-05  2021
# 2  United Kingdom   42    Male    Smart TV       1 Month 2023-02-28  2023
# 3       Australia   51  Female      Laptop       1 Month 2022-07-10  2022
# 4         Germany   33    Male  Smartphone       1 Month 2023-05-01  2023

# %% [markdown]
# ## Filtering

# %%
Netflix[(Netflix['Subscription Type'] == 'Standard') & (Netflix['year']==2022)]
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 3           4          Standard               12  10-07-2022
# 8           9          Standard               12  20-10-2022
# 23         24          Standard               12  03-04-2022
# 32         33          Standard               12  21-01-2022
# 33         34          Standard               12  25-05-2022
# ...       ...               ...              ...         ...
# 2487     2488          Standard               11  18-07-2022
# 2489     2490          Standard               10  17-07-2022
# 2492     2493          Standard               11  20-07-2022
# 2497     2498          Standard               12  09-08-2022
# 2498     2499          Standard               13  12-08-2022
#
#      Last Payment Date         Country  Age  Gender      Device Plan Duration  \
# 3           26-06-2023       Australia   51  Female      Laptop       1 Month
# ...

# %%
Netflix[(Netflix['Subscription Type'] == 'Standard') & (Netflix['year']==2021)]
# Out:
#     User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 6         7          Standard               12  09-12-2021        25-06-2023
# 12       13          Standard               12  30-11-2021        27-06-2023
# 17       18          Standard               12  18-10-2021        24-06-2023
# 22       23          Standard               12  05-12-2021        27-06-2023
# 27       28          Standard               12  27-09-2021        24-06-2023
# 37       38          Standard               12  05-11-2021        24-06-2023
# 47       48          Standard               12  15-09-2021        24-06-2023
# 57       58          Standard               12  08-10-2021        24-06-2023
# 67       68          Standard               12  09-11-2021        24-06-2023
#
#            Country  Age  Gender      Device Plan Duration     Date_N  year
# 6           Brazil   46    Male      Tablet       1 Month 2021-12-09  2021
# ...

# %%
Netflix[(Netflix['Subscription Type'] == 'Standard') & (Netflix['year']==2023)]
# Out:
#      User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 2          3          Standard               12  28-02-2023        27-06-2023
# 14        15          Standard               12  09-05-2023        28-06-2023
# 83        84          Standard               12  13-04-2023        25-06-2023
# 89        90          Standard               13  03-02-2023        23-06-2023
# 98        99          Standard               12  13-01-2023        24-06-2023
# 108      109          Standard               13  08-02-2023        25-06-2023
# 138      139          Standard               13  24-03-2023        23-06-2023
# 153      154          Standard               11  11-03-2023        27-06-2023
# 207      208          Standard               15  05-01-2023        23-06-2023
# 222      223          Standard               12  08-01-2023        25-06-2023
#
#             Country  Age  Gender      Device Plan Duration     Date_N  year
# ...

# %% [markdown]
# # Show only the Title of all subscription type that were joined in india only.

# %%
Netflix.head(10)
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
# 5        6           Premium               15  18-03-2022        27-06-2023
# 6        7          Standard               12  09-12-2021        25-06-2023
# 7        8             Basic               10  02-04-2023        24-06-2023
# 8        9          Standard               12  20-10-2022        23-06-2023
# 9       10           Premium               15  07-01-2023        22-06-2023
#
#           Country  Age  Gender      Device Plan Duration     Date_N  year
# ...

# %% [markdown]
# # no data found here it means no indian subscription here

# %%
Netflix[(Netflix['Subscription Type'] == 'Standard') & (Netflix['Country']=='india')]
# Out:
# Empty DataFrame
# Columns: [User ID, Subscription Type, Monthly Revenue, Join Date, Last Payment Date, Country, Age, Gender, Device, Plan Duration, Date_N, year]
# Index: []

# %% [markdown]
# # Find the subscribe in the title of premium with united states

# %%
Netflix[(Netflix['Subscription Type'] == 'Premium') & (Netflix['Country']=="United States")]
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 20         21           Premium               15  10-06-2023
# 30         31           Premium               15  03-02-2023
# 40         41           Premium               15  20-01-2023
# 50         51           Premium               15  27-02-2023
# 60         61           Premium               15  08-02-2023
# ...       ...               ...              ...         ...
# 2409     2410           Premium               12  02-08-2022
# 2425     2426           Premium               15  23-07-2022
# 2440     2441           Premium               10  07-10-2022
# 2455     2456           Premium               13  11-11-2022
# 2484     2485           Premium               14  25-07-2022
#
#      Last Payment Date        Country  Age  Gender      Device Plan Duration  \
# 20          22-06-2023  United States   26  Female      Laptop       1 Month
# ...

# %%
Netflix[(Netflix['Device']=='Laptop') & (Netflix['Country']=='United States')]
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 20         21           Premium               15  10-06-2023
# 40         41           Premium               15  20-01-2023
# 60         61           Premium               15  08-02-2023
# 130       131           Premium               15  06-10-2022
# 150       151             Basic               15  12-12-2022
# ...       ...               ...              ...         ...
# 2380     2381           Premium               12  30-10-2022
# 2422     2423          Standard               12  19-07-2022
# 2439     2440             Basic               14  29-09-2022
# 2482     2483             Basic               15  28-07-2022
# 2497     2498          Standard               12  09-08-2022
#
#      Last Payment Date        Country  Age  Gender  Device Plan Duration  \
# 20          22-06-2023  United States   26  Female  Laptop       1 Month
# 40          22-06-2023  United States   31  Female  Laptop       1 Month
# ...

# %% [markdown]
# # Show the top "Subscriber in this dateset"
#
# # Value_counts()

# %%
Netflix['Subscription Type'].value_counts().head(10)
# Out:
# Subscription Type
# Basic       999
# Standard    768
# Premium     733
# Name: count, dtype: int64

# %% [markdown]
# # Show all the records where " Subscription Type=Premimum" or "country is United States"
#
# # Filtering ( And, Or, opertors)

# %%
# Here present the dataset with subscription type premium and monthly revenue is 15 days with top five dayaset
Netflix[(Netflix['Subscription Type']=='Premium') & (Netflix['Monthly Revenue']==15)].head()
# Out:
#     User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 1         2           Premium               15  05-09-2021        22-06-2023
# 5         6           Premium               15  18-03-2022        27-06-2023
# 9        10           Premium               15  07-01-2023        22-06-2023
# 11       12           Premium               15  23-03-2023        28-06-2023
# 15       16           Premium               15  07-04-2022        27-06-2023
#
#    Country  Age  Gender    Device Plan Duration     Date_N  year
# 1   Canada   35  Female    Tablet       1 Month 2021-09-05  2021
# 5   France   29  Female  Smart TV       1 Month 2022-03-18  2022
# 9    Italy   44  Female  Smart TV       1 Month 2023-01-07  2023
# 11  Canada   45    Male    Tablet       1 Month 2023-03-23  2023
# 15  France   36    Male    Tablet       1 Month 2022-04-07  2022

# %%
# Here present the dataset with subscription type of premium, monthly revenue is 
 # 15 Days with count and sum functionality and present the total value.

Netflix[(Netflix['Subscription Type']=='Premium') & (Netflix['Monthly Revenue']==15)].count().sum()
# Out:
# 1572

# %% [markdown]
# # here present the dataset with subscription type of premium with according to device use laptop and country is united states

# %%
Netflix[(Netflix['Subscription Type']=='Premium') & (Netflix['Device']=='Laptop') & (Netflix['Country']=='United States')]
# Out:
#       User ID Subscription Type  Monthly Revenue   Join Date  \
# 20         21           Premium               15  10-06-2023
# 40         41           Premium               15  20-01-2023
# 60         61           Premium               15  08-02-2023
# 130       131           Premium               15  06-10-2022
# 190       191           Premium               10  08-07-2022
# 240       241           Premium               13  31-05-2022
# 250       251           Premium               15  25-06-2022
# 270       271           Premium               14  20-08-2022
# 340       341           Premium               13  24-08-2022
# 360       361           Premium               12  25-11-2022
# 380       381           Premium               10  14-07-2022
# 390       391           Premium               13  23-06-2022
# 400       401           Premium               12  17-07-2022
# 440       441           Premium               13  05-10-2022
# ...

# %%
# if you have find the unique value of device 
Netflix['Device'].unique()
# Out:
# array(['Smartphone', 'Tablet', 'Smart TV', 'Laptop'], dtype=object)

# %%
Netflix['Subscription Type'].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %% [markdown]
# # What is the maximum duration of a subscriber

# %%
Netflix.head()
# Out:
#    User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-2022        10-06-2023
# 1        2           Premium               15  05-09-2021        22-06-2023
# 2        3          Standard               12  28-02-2023        27-06-2023
# 3        4          Standard               12  10-07-2022        26-06-2023
# 4        5             Basic               10  01-05-2023        28-06-2023
#
#           Country  Age  Gender      Device Plan Duration     Date_N  year
# 0   United States   28    Male  Smartphone       1 Month 2022-01-15  2022
# 1          Canada   35  Female      Tablet       1 Month 2021-09-05  2021
# 2  United Kingdom   42    Male    Smart TV       1 Month 2023-02-28  2023
# 3       Australia   51  Female      Laptop       1 Month 2022-07-10  2022
# 4         Germany   33    Male  Smartphone       1 Month 2023-05-01  2023

# %%
Netflix['Plan Duration'].unique()
# Out:
# array(['1 Month'], dtype=object)

# %% [markdown]
# # sort the dataset with year

# %%
Netflix.sort_values(by='year',ascending=1)
# Out:
#      User ID Subscription Type  Monthly Revenue   Join Date Last Payment Date  \
# 47        48          Standard               12  15-09-2021        24-06-2023
# 67        68          Standard               12  09-11-2021        24-06-2023
# 126      127             Basic               10  23-11-2021        23-06-2023
# 22        23          Standard               12  05-12-2021        27-06-2023
# 116      117             Basic               15  30-10-2021        23-06-2023
# ..       ...               ...              ...         ...               ...
# 89        90          Standard               13  03-02-2023        23-06-2023
# 30        31           Premium               15  03-02-2023        22-06-2023
# 29        30             Basic               10  17-05-2023        22-06-2023
# 109      110             Basic               13  26-01-2023        24-06-2023
# 40        41           Premium               15  20-01-2023        22-06-2023
#
# ...
